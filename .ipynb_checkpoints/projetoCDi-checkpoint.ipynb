# %%
import yfinance as yf
import pandas as pd
import numpy as np
import quandl

# %%
ativos = ['ITSA4.SA','WEGE3.SA','CASH3.SA','ODPV3.SA']

# %%
inicio = '2020-01-01'
fim = '2021-10-06'

# %%
preco = pd.DataFrame()

for i in ativos :
  preco[i] = yf.download(i,start = inicio, end = fim)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
preco
# Out:
#              ITSA4.SA   WEGE3.SA  CASH3.SA   ODPV3.SA
# Date
# 2020-01-02  13.515140  17.296631       NaN  15.545967
# 2020-01-03  13.317355  17.075760       NaN  15.737893
# 2020-01-06  13.289102  17.119936       NaN  15.619080
# 2020-01-07  13.110154  17.252460       NaN  15.216950
# 2020-01-08  12.912370  16.599659       NaN  15.262650
# ...               ...        ...       ...        ...
# 2021-09-29  11.240000  39.869999      6.25  16.400000
# 2021-09-30  11.140000  39.630001      6.01  16.459999
# 2021-10-01  11.420000  40.169998      6.29  15.900000
# 2021-10-04  11.160000  38.779999      5.77  15.090000
# 2021-10-05  11.330000  37.529999      5.61  14.300000
#
# [435 rows x 4 columns]

# %%
compras = {'ITSA4.SA':1000,'WEGE3.SA':1000,'CASH3.SA':1000,'ODPV3.SA':1000}

# %%
compras_df = pd.Series(data=compras, index=list(compras.keys()))

# %%
primeiro = preco.iloc[0]

# %%
qtd_acoes = compras_df/primeiro

# %%
Pl = preco*qtd_acoes

# %%
Pl_filter = Pl.dropna(axis='rows')

# %%
Pl_filter['PL Total'] = Pl_filter.iloc[:].sum(axis = 1)

# %% [markdown]
# Chave da API

# %%
quandl.ApiConfig.api_key = "q3TN4ybJhcsjRBaPEiYi"

# %%
cdi = quandl.get("BCB/1161", start_date=inicio)

# %%
cdi.rename(columns={'Value':'CDI'}, inplace = True)

# %%
cdi = cdi[~(cdi == 0).any(axis=1)]

# %%
benchmarks = ['^BVSP','USDBRL=X']

# %%
benchs = pd.DataFrame()

# %%
for i in benchmarks:
    benchs[i] = yf.download(i, start=inicio, end=fim)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
benchs = pd.merge(benchs, cdi, how='inner', on='Date')

# %%
novo_df = pd.merge(benchs, Pl_filter, how='inner', on='Date')

# %%
lista = []

for i in range(len(novo_df)):
    if i == 0:
        lista.append(1)
    else:
        lista.append((lista[i-1])*(1+(novo_df.iloc[i-1])/100))

# %%
novo_df['CDB_100%_CDI'] = lista

# %% [markdown]
# # Deu erro

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pl_normalizado = novo_df/novo_df.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\FRANCI~1.NET\AppData\Local\Temp/ipykernel_7536/2970244222.py in <module>
# ----> 1 pl_normalizado = novo_df/novo_df.iloc[0]
#
# ~\.conda\envs\ai\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\.conda\envs\ai\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\.conda\envs\ai\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
pl_normalizado.rename(columns = {'^BVSP':'IBOV','USDBRL=X':'Dólar','PL Total':'Nossa Carteira'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FRANCI~1.NET\AppData\Local\Temp/ipykernel_7536/779127254.py in <module>
# ----> 1 pl_normalizado.rename(columns = {'^BVSP':'IBOV','USDBRL=X':'Dólar','PL Total':'Nossa Carteira'}, inplace = True)
#
# NameError: name 'pl_normalizado' is not defined
